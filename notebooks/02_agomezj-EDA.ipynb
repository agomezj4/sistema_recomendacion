# %%
import pandas as pd
import sys
import yaml
import os
import numpy as np

# %%
#pd.options.display.max_rows = None
#pd.options.display.max_columns = None

# %%
sys.path.append('../src/')
project_root = os.path.dirname(os.getcwd())

# %%
# Directorios para los archivos de parámetros y los datos
parameters_directory = os.path.join(project_root, 'src', 'parameters')
data_processed_directory = os.path.join(project_root, 'data', '02_processed')
# data_features_directory = os.path.join(project_root, 'data', 'featured')

# %% [markdown]
# EDA

# %%
processed_data_path = os.path.join(data_processed_directory,
                                       parameters['parameters_catalog']['processed_data_path'])

data_processed = pd.read_csv(processed_data_path)

# %%
data_processed
# Out:
#                  UUID_CLIENTE_CONSUMIDOR    PEDIDO FECHA_SOLUCION  \
# 0       5F333C92C61098CC840A180313615250  39562883     2023-09-28
# 1       323C3C3B1404F866097F000001615250  39758414     2023-10-14
# 2       6C2FA988251C4F35BD0A180313615250  39107912     2023-08-23
# 3       37908B3B6309B1549E7F000001615250  39197173     2023-08-30
# 4       85C5EF6E09B085614D0A180327615250  36658943     2023-01-18
# ...                                  ...       ...            ...
# 230995  6A52BE76792190DCC80A180313615250  38520606     2023-07-04
# 230996  5B22F2FCCC7C0EDD030A180313615250  39053488     2023-08-17
# 230997  638338102F3DDF3A610A180313615250  39250492     2023-09-03
# 230998  74FBAA8744AD8F128E0A180327615250  37580364     2023-04-08
# 230999  323AEC54D835C7AEDE7F000001615250  38188151     2023-05-31
#
#         COD_PRODUCTO              CATEGORIA  UNIDADES_BRUTAS  \
# 0              26605                Jabones                1
# 1              28308      Cuidado Capilar F                1
# 2              23610           Carnes Frias                1
# 3              18460      Cuidado Capilar F                1
# 4              28485           Cuidado Oral                1
# ...              ...                    ...              ...
# 230995         94473         Aseo Del Hogar                1
# 230996         33898                  Hogar                1
# 230997          1360  Bebidas Para Preparar                1
# 230998         97019               Galletas                1
# 230999         94066               Galletas                4
#
#         VENTA_BRUTA_CON_IVA        DEPARTAMENTO        CIUDAD  \
# 0                   10043.0           ANTIOQUIA      MEDELLÍN
# 1                   23859.0     VALLE DEL CAUCA          CALI
# 2                   20152.0     VALLE DEL CAUCA          CALI
# 3                   21500.0  NORTE DE SANTANDER      PAMPLONA
# 4                   10100.0        BOGOTÁ, D.C.  BOGOTÁ, D.C.
# ...                     ...                 ...           ...
# 230995               5610.0        BOGOTÁ, D.C.  BOGOTÁ, D.C.
# 230996              10132.0        BOGOTÁ, D.C.  BOGOTÁ, D.C.
# 230997              21640.0           ANTIOQUIA       LA CEJA
# 230998              11200.0           ANTIOQUIA         BELLO
# 230999              18656.0           ANTIOQUIA      MEDELLÍN
#
#        GENERO_DIM_CLIENTE FECHANACIMIENTO_DIM_CLIENTE
# 0                       F                  1984-05-03
# 1                       F                  1972-12-26
# 2                       F                  1991-11-18
# 3                       F                  1983-07-16
# 4                       F                  1971-06-18
# ...                   ...                         ...
# 230995                  F                  1984-01-01
# 230996                  F                  1990-05-17
# 230997                  F                  1996-08-27
# 230998                  F                  1972-09-20
# 230999                  F                  1986-11-25
#
# [231000 rows x 11 columns]
